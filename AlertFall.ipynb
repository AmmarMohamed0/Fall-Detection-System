# %%
import cv2
import cvzone
import math
from ultralytics import YOLO
import pygame

# Initialize pygame mixer
pygame.mixer.init()
alert_sound = pygame.mixer.Sound("alert.mp3")  

cap = cv2.VideoCapture('fall.mp4')

model = YOLO('yolov8s.pt')

classnames = []
with open('coco.txt', 'r') as f:
    classnames = f.read().splitlines()

while True:
    ret, frame = cap.read()
    if not ret:  # Exit if video ends
        break
    frame = cv2.resize(frame, (980, 740))

    results = model(frame)

    for info in results:
        parameters = info.boxes
        for box in parameters:
            x1, y1, x2, y2 = box.xyxy[0]
            x1, y1, x2, y2 = int(x1), int(y1), int(x2), int(y2)
            confidence = box.conf[0]
            class_detect = box.cls[0]
            class_detect = int(class_detect)
            class_detect = classnames[class_detect]
            conf = math.ceil(confidence * 100)

            # Implement fall detection using the coordinates x1, y1, x2, y2
            height = y2 - y1
            width = x2 - x1
            threshold = height - width

            if conf > 10 and class_detect == 'person':
                cvzone.cornerRect(frame, [x1, y1, width, height], l=30, rt=6)
                cvzone.putTextRect(frame, f'{class_detect}', [x1 + 8, y1 - 12], thickness=2, scale=2)

            if threshold < 0:
                cvzone.putTextRect(frame, 'Fall Detected', [x1, y1 - 50], thickness=2, scale=2)
                
                pygame.mixer.Sound.play(alert_sound)
            else:
                pass

    cv2.imshow('frame', frame)
    if cv2.waitKey(25) & 0xFF == ord('q'):
        break
pygame.mixer.stop()
cap.release()
cv2.destroyAllWindows()
# Out:
# pygame 2.5.2 (SDL 2.28.3, Python 3.11.8)
# Hello from the pygame community. https://www.pygame.org/contribute.html
#
# 0: 512x640 2 persons, 100.5ms
# Speed: 10.0ms preprocess, 100.5ms inference, 229.7ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 persons, 29.0ms
# Speed: 5.5ms preprocess, 29.0ms inference, 3.6ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 persons, 30.0ms
# Speed: 4.3ms preprocess, 30.0ms inference, 4.5ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 persons, 29.4ms
# Speed: 3.5ms preprocess, 29.4ms inference, 2.1ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 persons, 29.8ms
# Speed: 4.5ms preprocess, 29.8ms inference, 3.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 persons, 29.6ms
# Speed: 4.9ms preprocess, 29.6ms inference, 4.1ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 28.3ms
# Speed: 3.0ms preprocess, 28.3ms inference, 2.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 28.0ms
# Speed: 4.6ms preprocess, 28.0ms inference, 2.5ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 27.8ms
# Speed: 3.5ms preprocess, 27.8ms inference, 4.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 27.8ms
# Speed: 4.0ms preprocess, 27.8ms inference, 2.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 27.6ms
# Speed: 5.0ms preprocess, 27.6ms inference, 3.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 28.2ms
# Speed: 4.1ms preprocess, 28.2ms inference, 3.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 27.6ms
# Speed: 4.5ms preprocess, 27.6ms inference, 3.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 27.7ms
# Speed: 5.0ms preprocess, 27.7ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 27.2ms
# Speed: 3.0ms preprocess, 27.2ms inference, 9.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 27.6ms
# Speed: 4.5ms preprocess, 27.6ms inference, 4.5ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 27.9ms
# Speed: 5.0ms preprocess, 27.9ms inference, 3.1ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 29.7ms
# Speed: 5.0ms preprocess, 29.7ms inference, 4.5ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 27.7ms
# Speed: 4.0ms preprocess, 27.7ms inference, 2.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 27.2ms
# Speed: 4.5ms preprocess, 27.2ms inference, 3.5ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 27.6ms
# Speed: 4.0ms preprocess, 27.6ms inference, 3.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 27.8ms
# Speed: 4.0ms preprocess, 27.8ms inference, 3.7ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 28.3ms
# Speed: 4.6ms preprocess, 28.3ms inference, 8.5ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 27.6ms
# Speed: 7.6ms preprocess, 27.6ms inference, 4.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 27.1ms
# Speed: 4.0ms preprocess, 27.1ms inference, 2.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 27.4ms
# Speed: 4.0ms preprocess, 27.4ms inference, 2.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 27.2ms
# Speed: 3.0ms preprocess, 27.2ms inference, 2.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 27.2ms
# Speed: 5.0ms preprocess, 27.2ms inference, 2.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 28.4ms
# Speed: 4.0ms preprocess, 28.4ms inference, 1.5ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 27.7ms
# Speed: 4.6ms preprocess, 27.7ms inference, 1.4ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 26.4ms
# Speed: 4.5ms preprocess, 26.4ms inference, 2.6ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 27.8ms
# Speed: 4.1ms preprocess, 27.8ms inference, 2.1ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 27.2ms
# Speed: 4.1ms preprocess, 27.2ms inference, 2.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 27.1ms
# Speed: 5.0ms preprocess, 27.1ms inference, 2.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 27.6ms
# Speed: 4.6ms preprocess, 27.6ms inference, 2.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 27.6ms
# Speed: 4.0ms preprocess, 27.6ms inference, 2.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 27.6ms
# Speed: 4.0ms preprocess, 27.6ms inference, 2.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 27.6ms
# Speed: 4.0ms preprocess, 27.6ms inference, 3.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 26.7ms
# Speed: 4.0ms preprocess, 26.7ms inference, 3.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 26.5ms
# Speed: 4.5ms preprocess, 26.5ms inference, 2.5ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 26.1ms
# Speed: 5.2ms preprocess, 26.1ms inference, 3.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 26.6ms
# Speed: 4.0ms preprocess, 26.6ms inference, 2.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 tv, 26.2ms
# Speed: 3.5ms preprocess, 26.2ms inference, 2.5ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 27.0ms
# Speed: 2.9ms preprocess, 27.0ms inference, 2.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 32.3ms
# Speed: 6.1ms preprocess, 32.3ms inference, 4.5ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 27.6ms
# Speed: 4.5ms preprocess, 27.6ms inference, 4.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 27.4ms
# Speed: 3.0ms preprocess, 27.4ms inference, 2.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 27.5ms
# Speed: 3.0ms preprocess, 27.5ms inference, 2.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 26.8ms
# Speed: 3.0ms preprocess, 26.8ms inference, 2.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 26.9ms
# Speed: 4.0ms preprocess, 26.9ms inference, 2.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 27.6ms
# Speed: 4.3ms preprocess, 27.6ms inference, 4.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 26.6ms
# Speed: 4.0ms preprocess, 26.6ms inference, 3.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 27.6ms
# Speed: 4.5ms preprocess, 27.6ms inference, 2.5ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 27.9ms
# Speed: 3.5ms preprocess, 27.9ms inference, 2.2ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 27.2ms
# Speed: 4.0ms preprocess, 27.2ms inference, 2.1ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 27.3ms
# Speed: 5.5ms preprocess, 27.3ms inference, 4.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 27.2ms
# Speed: 4.0ms preprocess, 27.2ms inference, 2.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 27.0ms
# Speed: 4.0ms preprocess, 27.0ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 27.0ms
# Speed: 4.1ms preprocess, 27.0ms inference, 3.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 27.2ms
# Speed: 4.0ms preprocess, 27.2ms inference, 4.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 26.9ms
# Speed: 4.5ms preprocess, 26.9ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 26.6ms
# Speed: 4.0ms preprocess, 26.6ms inference, 4.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 27.3ms
# Speed: 4.5ms preprocess, 27.3ms inference, 2.5ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 26.1ms
# Speed: 5.1ms preprocess, 26.1ms inference, 2.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 26.2ms
# Speed: 4.0ms preprocess, 26.2ms inference, 4.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 26.5ms
# Speed: 4.0ms preprocess, 26.5ms inference, 2.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 26.7ms
# Speed: 3.0ms preprocess, 26.7ms inference, 3.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 26.8ms
# Speed: 4.0ms preprocess, 26.8ms inference, 2.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 26.9ms
# Speed: 4.0ms preprocess, 26.9ms inference, 2.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 27.1ms
# Speed: 5.1ms preprocess, 27.1ms inference, 4.5ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 25.7ms
# Speed: 3.0ms preprocess, 25.7ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 26.6ms
# Speed: 4.2ms preprocess, 26.6ms inference, 2.9ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 26.6ms
# Speed: 4.0ms preprocess, 26.6ms inference, 4.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 26.6ms
# Speed: 4.0ms preprocess, 26.6ms inference, 3.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 27.1ms
# Speed: 4.0ms preprocess, 27.1ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 27.3ms
# Speed: 4.0ms preprocess, 27.3ms inference, 2.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 27.8ms
# Speed: 3.0ms preprocess, 27.8ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 26.6ms
# Speed: 3.5ms preprocess, 26.6ms inference, 2.5ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 27.9ms
# Speed: 4.5ms preprocess, 27.9ms inference, 3.7ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 26.5ms
# Speed: 5.0ms preprocess, 26.5ms inference, 3.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 26.4ms
# Speed: 4.0ms preprocess, 26.4ms inference, 3.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 26.6ms
# Speed: 4.5ms preprocess, 26.6ms inference, 2.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 27.0ms
# Speed: 4.0ms preprocess, 27.0ms inference, 2.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 26.6ms
# Speed: 4.0ms preprocess, 26.6ms inference, 2.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 27.4ms
# Speed: 3.0ms preprocess, 27.4ms inference, 3.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 26.7ms
# Speed: 4.1ms preprocess, 26.7ms inference, 2.5ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 26.1ms
# Speed: 4.0ms preprocess, 26.1ms inference, 2.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 26.7ms
# Speed: 3.6ms preprocess, 26.7ms inference, 2.6ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 26.7ms
# Speed: 4.5ms preprocess, 26.7ms inference, 2.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 tv, 27.3ms
# Speed: 5.5ms preprocess, 27.3ms inference, 2.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 tv, 26.9ms
# Speed: 4.6ms preprocess, 26.9ms inference, 2.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 26.9ms
# Speed: 3.0ms preprocess, 26.9ms inference, 4.8ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 refrigerator, 27.6ms
# Speed: 5.5ms preprocess, 27.6ms inference, 1.5ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 suitcase, 27.2ms
# Speed: 4.2ms preprocess, 27.2ms inference, 3.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 suitcase, 27.5ms
# Speed: 4.1ms preprocess, 27.5ms inference, 2.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 suitcase, 26.2ms
# Speed: 3.5ms preprocess, 26.2ms inference, 2.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 car, 27.3ms
# Speed: 4.0ms preprocess, 27.3ms inference, 3.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 26.8ms
# Speed: 4.2ms preprocess, 26.8ms inference, 3.1ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 26.6ms
# Speed: 3.2ms preprocess, 26.6ms inference, 2.5ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 26.7ms
# Speed: 4.0ms preprocess, 26.7ms inference, 3.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 27.0ms
# Speed: 4.5ms preprocess, 27.0ms inference, 2.1ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 27.0ms
# Speed: 5.3ms preprocess, 27.0ms inference, 2.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 26.5ms
# Speed: 4.0ms preprocess, 26.5ms inference, 2.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 27.3ms
# Speed: 4.0ms preprocess, 27.3ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 27.1ms
# Speed: 4.0ms preprocess, 27.1ms inference, 3.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 26.8ms
# Speed: 4.0ms preprocess, 26.8ms inference, 3.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 27.0ms
# Speed: 3.7ms preprocess, 27.0ms inference, 2.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 28.0ms
# Speed: 4.0ms preprocess, 28.0ms inference, 2.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 26.9ms
# Speed: 4.5ms preprocess, 26.9ms inference, 2.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 26.7ms
# Speed: 3.5ms preprocess, 26.7ms inference, 1.9ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 27.6ms
# Speed: 3.0ms preprocess, 27.6ms inference, 2.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 27.2ms
# Speed: 3.0ms preprocess, 27.2ms inference, 3.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 26.8ms
# Speed: 4.3ms preprocess, 26.8ms inference, 2.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 27.1ms
# Speed: 3.5ms preprocess, 27.1ms inference, 2.5ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 26.0ms
# Speed: 4.5ms preprocess, 26.0ms inference, 3.5ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 26.6ms
# Speed: 4.0ms preprocess, 26.6ms inference, 2.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 26.8ms
# Speed: 3.5ms preprocess, 26.8ms inference, 3.5ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 26.5ms
# Speed: 4.2ms preprocess, 26.5ms inference, 1.9ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 26.9ms
# Speed: 4.0ms preprocess, 26.9ms inference, 2.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 27.7ms
# Speed: 3.8ms preprocess, 27.7ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 tennis racket, 27.6ms
# Speed: 4.5ms preprocess, 27.6ms inference, 2.1ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 26.3ms
# Speed: 4.0ms preprocess, 26.3ms inference, 2.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 skateboard, 1 tv, 26.9ms
# Speed: 4.0ms preprocess, 26.9ms inference, 2.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 skateboard, 1 tv, 26.7ms
# Speed: 4.0ms preprocess, 26.7ms inference, 2.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 2 skateboards, 27.7ms
# Speed: 4.6ms preprocess, 27.7ms inference, 1.8ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 tv, 26.2ms
# Speed: 4.0ms preprocess, 26.2ms inference, 2.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 tv, 26.7ms
# Speed: 4.0ms preprocess, 26.7ms inference, 3.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 tv, 27.3ms
# Speed: 4.1ms preprocess, 27.3ms inference, 2.5ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 tv, 27.0ms
# Speed: 3.5ms preprocess, 27.0ms inference, 2.5ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 tv, 26.6ms
# Speed: 4.4ms preprocess, 26.6ms inference, 1.9ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 tv, 26.6ms
# Speed: 4.2ms preprocess, 26.6ms inference, 2.5ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 tv, 26.7ms
# Speed: 4.2ms preprocess, 26.7ms inference, 3.1ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 tv, 27.3ms
# Speed: 4.0ms preprocess, 27.3ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 tv, 26.8ms
# Speed: 3.1ms preprocess, 26.8ms inference, 2.2ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 tv, 27.2ms
# Speed: 3.3ms preprocess, 27.2ms inference, 2.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 tv, 28.0ms
# Speed: 3.5ms preprocess, 28.0ms inference, 2.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 tv, 26.9ms
# Speed: 7.0ms preprocess, 26.9ms inference, 3.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 tv, 38.9ms
# Speed: 7.1ms preprocess, 38.9ms inference, 5.6ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 tv, 26.4ms
# Speed: 3.5ms preprocess, 26.4ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 tv, 26.5ms
# Speed: 4.0ms preprocess, 26.5ms inference, 2.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 tv, 26.9ms
# Speed: 3.0ms preprocess, 26.9ms inference, 5.5ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 tv, 26.2ms
# Speed: 3.0ms preprocess, 26.2ms inference, 2.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 tv, 27.1ms
# Speed: 3.2ms preprocess, 27.1ms inference, 2.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 tv, 26.6ms
# Speed: 4.9ms preprocess, 26.6ms inference, 4.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 tv, 26.7ms
# Speed: 3.5ms preprocess, 26.7ms inference, 2.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 tv, 26.6ms
# Speed: 4.5ms preprocess, 26.6ms inference, 3.1ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 tv, 27.1ms
# Speed: 4.0ms preprocess, 27.1ms inference, 2.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 tv, 26.4ms
# Speed: 4.0ms preprocess, 26.4ms inference, 2.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 tv, 27.0ms
# Speed: 3.0ms preprocess, 27.0ms inference, 2.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 tv, 26.7ms
# Speed: 4.0ms preprocess, 26.7ms inference, 2.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 tv, 26.6ms
# Speed: 3.0ms preprocess, 26.6ms inference, 3.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 tv, 27.0ms
# Speed: 3.0ms preprocess, 27.0ms inference, 3.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 tv, 27.5ms
# Speed: 3.6ms preprocess, 27.5ms inference, 1.7ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 tv, 26.2ms
# Speed: 3.5ms preprocess, 26.2ms inference, 3.5ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 tv, 26.2ms
# Speed: 4.0ms preprocess, 26.2ms inference, 3.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 tv, 26.3ms
# Speed: 4.2ms preprocess, 26.3ms inference, 2.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 tv, 26.0ms
# Speed: 3.3ms preprocess, 26.0ms inference, 2.5ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 tv, 27.1ms
# Speed: 3.0ms preprocess, 27.1ms inference, 2.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 tv, 27.1ms
# Speed: 4.0ms preprocess, 27.1ms inference, 2.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 tv, 26.6ms
# Speed: 4.0ms preprocess, 26.6ms inference, 2.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 person, 1 tv, 26.7ms
# Speed: 5.6ms preprocess, 26.7ms inference, 3.1ms postprocess per image at shape (1, 3, 512, 640)
